# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\depak\\OneDrive\\Desktop\\rkkk\\bbb.csv")
df=pd.DataFrame(d)
print(d)
# Out:
#                     tournament           home  home_goal  away_goal  \
# 0               Premier League        Arsenal        0.0        0.0
# 1               Premier League      Leicester        0.0        0.0
# 2               Premier League      Liverpool        0.0        0.0
# 3               Premier League    Bournemouth        0.0        0.0
# 4               Premier League         Fulham        0.0        0.0
# ...                        ...            ...        ...        ...
# 21796  England National League  Kidderminster        2.0        2.0
# 21797  England National League   Lincoln City        1.0        1.0
# 21798  England National League        Torquay        1.0        0.0
# 21799  England National League       Tranmere        1.0        0.0
# 21800  England National League        Welling        1.0        0.0
#
#                away  home_corner  away_corner  home_attack  away_attack  \
# 0           Chelsea          0.0          0.0          NaN          NaN
# ...

# %%
df.head()
# Out:
#        tournament         home  home_goal  away_goal       away  home_corner  \
# 0  Premier League      Arsenal        0.0        0.0    Chelsea          0.0
# 1  Premier League    Leicester        0.0        0.0    Everton          0.0
# 2  Premier League    Liverpool        0.0        0.0  Tottenham          0.0
# 3  Premier League  Bournemouth        0.0        0.0      Leeds          0.0
# 4  Premier League       Fulham        0.0        0.0   Man City          0.0
#
#    away_corner  home_attack  away_attack  home_shots  away_shots      time  \
# 0          0.0          NaN          NaN         NaN         NaN  20:00:00
# 1          0.0          NaN          NaN         NaN         NaN  20:00:00
# 2          0.0          NaN          NaN         NaN         NaN  16:30:00
# 3          0.0          NaN          NaN         NaN         NaN  14:00:00
# 4          0.0          NaN          NaN         NaN         NaN  14:00:00
#
# ...

# %%
df.tail()
# Out:
#                     tournament           home  home_goal  away_goal  \
# 21796  England National League  Kidderminster        2.0        2.0
# 21797  England National League   Lincoln City        1.0        1.0
# 21798  England National League        Torquay        1.0        0.0
# 21799  England National League       Tranmere        1.0        0.0
# 21800  England National League        Welling        1.0        0.0
#
#                away  home_corner  away_corner  home_attack  away_attack  \
# 21796       Grimsby          2.0          4.0          NaN          NaN
# 21797    Cheltenham          8.0          6.0          NaN          NaN
# 21798  Macclesfield          4.0          7.0          NaN          NaN
# 21799        Woking          2.0          7.0          NaN          NaN
# 21800      Guiseley          2.0          3.0          NaN          NaN
#
#        home_shots  away_shots      time        date  ht_diff  at_diff  \
# ...

# %%
df.sort_values("total_corners")
# Out:
#                     tournament                home  home_goal  away_goal  \
# 0               Premier League             Arsenal        0.0        0.0
# 8301          England League 1  Accrington Stanley        0.0        0.0
# 17420         England League 2                Bury        0.0        0.0
# 17770         England League 2          Shrewsbury        0.0        0.0
# 17857  England National League           Aldershot        0.0        0.0
# ...                        ...                 ...        ...        ...
# 2888            Premier League             Norwich        1.0        2.0
# 17143         England League 2              Barnet        2.0        0.0
# 7801      England Championship              Bolton        1.0        1.0
# 12040         England League 1                Bury        1.0        0.0
# 20836  England National League            Guiseley        3.0        2.0
#
#                 away  home_corner  away_corner  home_attack  away_attack  \
# ...

# %%
df.sort_values("home_corner")
# Out:
#                  tournament            home  home_goal  away_goal  \
# 0            Premier League         Arsenal        0.0        0.0
# 13895      England League 2  Bristol Rovers        1.0        2.0
# 13759      England League 2        Carlisle        2.0        0.0
# 13750      England League 2   Leyton Orient        2.0        2.0
# 1210         Premier League  Crystal Palace        0.0        2.0
# ...                     ...             ...        ...        ...
# 13622      England League 2  Bristol Rovers        7.0        0.0
# 14180      England League 2    Forest Green        3.0        2.0
# 2484         Premier League         Man Utd        0.0        0.0
# 6666   England Championship       Newcastle        1.0        1.0
# 11766      England League 1       Sheff Utd        2.0        1.0
#
#               away  home_corner  away_corner  home_attack  away_attack  \
# 0          Chelsea          0.0          0.0          NaN          NaN
# ...

# %%
df.sort_values("away_corner")
# Out:
#                     tournament                home  home_goal  away_goal  \
# 0               Premier League             Arsenal        0.0        0.0
# 9978          England League 1  Accrington Stanley        2.0        1.0
# 9990          England League 1          Gillingham        2.0        0.0
# 18663  England National League        Notts County        3.0        1.0
# 9995          England League 1           Doncaster        3.0        1.0
# ...                        ...                 ...        ...        ...
# 16731         England League 2        Crawley Town        1.0        1.0
# 12040         England League 1                Bury        1.0        0.0
# 16986         England League 2                York        2.0        1.0
# 212             Premier League         Bournemouth        2.0        3.0
# 12495         England League 1                Bury        3.0        4.0
#
#                  away  home_corner  away_corner  home_attack  away_attack  \
# ...

# %%
df.sort_values("home_goal")
# Out:
#                     tournament            home  home_goal  away_goal  \
# 0               Premier League         Arsenal        0.0        0.0
# 14726         England League 2     Northampton        0.0        1.0
# 14728         England League 2      Scunthorpe        0.0        2.0
# 5541      England Championship          Bolton        0.0        2.0
# 14737         England League 2  Newport County        0.0        1.0
# ...                        ...             ...        ...        ...
# 21515  England National League         Chester        8.0        2.0
# 16215         England League 2           Luton        8.0        2.0
# 1387            Premier League        Man City        8.0        0.0
# 20962  England National League        Tranmere        9.0        0.0
# 301             Premier League       Liverpool        9.0        0.0
#
#                  away  home_corner  away_corner  home_attack  away_attack  \
# ...

# %%
df.sort_values("away_goal")
# Out:
#                     tournament            home  home_goal  away_goal  \
# 0               Premier League         Arsenal        0.0        0.0
# 10696         England League 1  Bristol Rovers        0.0        0.0
# 10697         England League 1        Charlton        2.0        0.0
# 10699         England League 1           Luton        2.0        0.0
# 10702         England League 1      Portsmouth        1.0        0.0
# ...                        ...             ...        ...        ...
# 9034          England League 1      Gillingham        2.0        7.0
# 11146         England League 1      Oxford Utd        0.0        7.0
# 8110      England Championship      Birmingham        0.0        8.0
# 21509  England National League      Cheltenham        4.0        9.0
# 1349            Premier League     Southampton        0.0        9.0
#
#                  away  home_corner  away_corner  home_attack  away_attack  \
# ...
