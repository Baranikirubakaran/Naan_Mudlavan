# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\depak\\OneDrive\\Desktop\\rkkk\\icpc-full.csv")
df=pd.DataFrame(d)
print(d)
# Out:
#       Year        Date         Host       City  \
# 0     1999  1999-04-11  Netherlands  Eindhoven
# 1     1999  1999-04-11  Netherlands  Eindhoven
# 2     1999  1999-04-11  Netherlands  Eindhoven
# 3     1999  1999-04-11  Netherlands  Eindhoven
# 4     1999  1999-04-11  Netherlands  Eindhoven
# ...    ...         ...          ...        ...
# 2303  2021  2022-11-10   Bangladesh      Dhaka
# 2304  2021  2022-11-10   Bangladesh      Dhaka
# 2305  2021  2022-11-10   Bangladesh      Dhaka
# 2306  2021  2022-11-10   Bangladesh      Dhaka
# 2307  2021  2022-11-10   Bangladesh      Dhaka
#
#                                           Venue   Rank  \
# 0            Eindhoven University of Technology    1.0
# 1            Eindhoven University of Technology    2.0
# 2            Eindhoven University of Technology    3.0
# 3            Eindhoven University of Technology    4.0
# 4            Eindhoven University of Technology    5.0
# ...                                         ...    ...
# ...

# %%
df.head()
# Out:
#    Year        Date         Host       City  \
# 0  1999  1999-04-11  Netherlands  Eindhoven
# 1  1999  1999-04-11  Netherlands  Eindhoven
# 2  1999  1999-04-11  Netherlands  Eindhoven
# 3  1999  1999-04-11  Netherlands  Eindhoven
# 4  1999  1999-04-11  Netherlands  Eindhoven
#
#                                 Venue  Rank  \
# 0  Eindhoven University of Technology   1.0
# 1  Eindhoven University of Technology   2.0
# 2  Eindhoven University of Technology   3.0
# 3  Eindhoven University of Technology   4.0
# 4  Eindhoven University of Technology   5.0
#
#                                           University        Country  \
# 0                             University of Waterloo         Canada
# 1                Albert-Ludwigs-Universität Freiburg        Germany
# 2  St. Petersburg Institute of Fine Mechanics & O...         Russia
# 3                            University of Bucharest        Romania
# 4                                    Duke University  United States
#
# ...

# %%
df.tail()
# Out:
#       Year        Date        Host   City  \
# 2303  2021  2022-11-10  Bangladesh  Dhaka
# 2304  2021  2022-11-10  Bangladesh  Dhaka
# 2305  2021  2022-11-10  Bangladesh  Dhaka
# 2306  2021  2022-11-10  Bangladesh  Dhaka
# 2307  2021  2022-11-10  Bangladesh  Dhaka
#
#                                           Venue   Rank  \
# 2303  International Convention City Bashundhara  126.0
# 2304  International Convention City Bashundhara  126.0
# 2305  International Convention City Bashundhara  126.0
# 2306  International Convention City Bashundhara  126.0
# 2307  International Convention City Bashundhara  126.0
#
#                                      University     Country             Team  \
# 2303                 German University in Cairo       Egypt         Treevial
# 2304                  Syrian Virtual University       Syria         Traitors
# 2305         Universidad Tecnologica de Pereira    Colombia      UTP - Lucas
# ...

# %%
df.sort_values("Score")
# Out:
#       Year        Date        Host           City  \
# 2307  2021  2022-11-10  Bangladesh          Dhaka
# 387   2004  2004-03-31     Czechia         Prague
# 386   2004  2004-03-31     Czechia         Prague
# 385   2004  2004-03-31     Czechia         Prague
# 1396  2014  2014-06-25      Russia  Yekaterinburg
# ...    ...         ...         ...            ...
# 834   2009  2009-04-21      Sweden      Stockholm
# 835   2009  2009-04-21      Sweden      Stockholm
# 836   2009  2009-04-21      Sweden      Stockholm
# 837   2009  2009-04-21      Sweden      Stockholm
# 838   2009  2009-04-21      Sweden      Stockholm
#
#                                           Venue   Rank  \
# 2307  International Convention City Bashundhara  126.0
# 387                Municipal House (Obecni Dum)   68.0
# 386                Municipal House (Obecni Dum)   68.0
# 385                Municipal House (Obecni Dum)   68.0
# 1396               Palace of Team Sports (DIVS)  103.0
# ...

# %%
df.sort_values("Total",ascending=False)
# Out:
#       Year        Date         Host       City  \
# 2129  2020  2021-10-05       Russia     Moscow
# 2084  2020  2021-10-05       Russia     Moscow
# 2166  2020  2021-10-05       Russia     Moscow
# 2165  2020  2021-10-05       Russia     Moscow
# 2164  2020  2021-10-05       Russia     Moscow
# ...    ...         ...          ...        ...
# 400   2005  2005-04-06        China   Shanghai
# 399   2005  2005-04-06        China   Shanghai
# 398   2005  2005-04-06        China   Shanghai
# 397   2005  2005-04-06        China   Shanghai
# 0     1999  1999-04-11  Netherlands  Eindhoven
#
#                                    Venue   Rank  \
# 2129                       Moscow Manege   71.0
# 2084                       Moscow Manege   26.0
# 2166                       Moscow Manege  108.0
# 2165                       Moscow Manege  107.0
# 2164                       Moscow Manege  106.0
# ...                                  ...    ...
# 400              Pudong Shangri-La Hotel   10.0
# ...

# %%
df.sort_values("Score Percentage",ascending=False)
# Out:
#       Year        Date        Host              City  \
# 391   2005  2005-04-06       China          Shanghai
# 1397  2015  2015-05-20     Morocco         Marrakech
# 2176  2021  2022-11-10  Bangladesh             Dhaka
# 1924  2019  2019-04-04    Portugal             Porto
# 1159  2013  2013-07-03      Russia  Saint Petersburg
# ...    ...         ...         ...               ...
# 834   2009  2009-04-21      Sweden         Stockholm
# 835   2009  2009-04-21      Sweden         Stockholm
# 836   2009  2009-04-21      Sweden         Stockholm
# 837   2009  2009-04-21      Sweden         Stockholm
# 838   2009  2009-04-21      Sweden         Stockholm
#
#                                           Venue  Rank  \
# 391                     Pudong Shangri-La Hotel   1.0
# 1397                Palmeraie Conference Center   1.0
# 2176  International Convention City Bashundhara   1.0
# 1924                  Alfândega Congress Centre   1.0
# ...

# %%
df.sort_values("Penalty",ascending=False)
# Out:
#       Year        Date     Host       City  \
# 2065  2020  2021-10-05   Russia     Moscow
# 2064  2020  2021-10-05   Russia     Moscow
# 2069  2020  2021-10-05   Russia     Moscow
# 1397  2015  2015-05-20  Morocco  Marrakech
# 740   2009  2009-04-21   Sweden  Stockholm
# ...    ...         ...      ...        ...
# 834   2009  2009-04-21   Sweden  Stockholm
# 835   2009  2009-04-21   Sweden  Stockholm
# 836   2009  2009-04-21   Sweden  Stockholm
# 837   2009  2009-04-21   Sweden  Stockholm
# 838   2009  2009-04-21   Sweden  Stockholm
#
#                                     Venue  Rank  \
# 2065                        Moscow Manege   7.0
# 2064                        Moscow Manege   6.0
# 2069                        Moscow Manege  11.0
# 1397          Palmeraie Conference Center   1.0
# 740   KTH – Royal Institute of Technology   2.0
# ...                                   ...   ...
# 834   KTH – Royal Institute of Technology   NaN
# 835   KTH – Royal Institute of Technology   NaN
# ...
